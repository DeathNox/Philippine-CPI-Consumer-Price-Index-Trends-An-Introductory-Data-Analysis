# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import plotly.express as px
import seaborn as sns

# %config InlineBackend.figure_format = 'retina'

import warnings
warnings.filterwarnings(action='ignore', category=FutureWarning)

# %%
# Load and clean your Excel file (skip the top header rows)
df = pd.read_excel("Original_Data/Statistical Tables on June 2025 CPI for All Income Households.xlsx",
                   sheet_name="table 1", skiprows=5)

# Rename the first column for clarity
df.rename(columns={df.columns[0]: "Commodity Group"}, inplace=True)

# Drop empty columns and rows
df.dropna(axis=1, how='all', inplace=True)
df = df[df["Commodity Group"].notna()]

# %%
df = df.rename(columns={'Unnamed: 1': 'Commodity Group'})

df.head()
# Out:
#   Commodity Group                                   Commodity Group    Jan  \
# 1       ALL ITEMS                                               NaN  124.8
# 2            01 -                  Food and Non-Alcoholic Beverages  128.9
# 3            02 -                   Alcoholic Beverages and Tobacco  174.7
# 4            03 -                             Clothing and Footwear    117
# 5            04 -  Housing, Water, Electricity, Gas and Other Fuels  118.8
#
#      Feb    Mar    Apr    May Unnamed: 11    Jun    Jul    Aug    Sep    Oct  \
# 1  125.5  125.6  125.5  125.6         NaN  125.6  126.5  126.6  126.3  126.5
# 2  129.3  128.9  128.7  128.7         NaN  129.5  130.4  130.4  129.8  130.4
# 3  175.9  176.3  176.5  176.8         NaN    177    177  177.2  177.5  177.8
# 4  117.4  117.9  118.2  118.4         NaN  118.5  118.7    119  119.1  119.2
# 5  119.8  119.8  119.2  119.8         NaN  118.4    120  120.9  121.2  120.9
#
# ...

# %% [markdown]
# Transform Data

# %%
# ...existing code...

# Set 'Commodity Group' as columns, months as index
df_transformed = df.set_index('Commodity Group').T

# Optional: Reset index and rename for clarity
df_transformed = df_transformed.reset_index().rename(columns={'index': 'Month'})

df_transformed.head()
# ...existing code...
# Out:
# Commodity Group Month (ALL ITEMS, nan)  \
# 0                 Jan            124.8
# 1                 Feb            125.5
# 2                 Mar            125.6
# 3                 Apr            125.5
# 4                 May            125.6
#
# Commodity Group (01 -, Food and Non-Alcoholic Beverages)  \
# 0                                                  128.9
# 1                                                  129.3
# 2                                                  128.9
# 3                                                  128.7
# 4                                                  128.7
#
# Commodity Group (02 -, Alcoholic Beverages and Tobacco)  \
# 0                                                 174.7
# 1                                                 175.9
# 2                                                 176.3
# 3                                                 176.5
# 4                                                 176.8
#
# ...

# %%
import numpy as np

df_transformed = df_transformed.rename(columns={'Unknown': 'All items'})

# %%
df_transformed = df_transformed[df_transformed['Month'] != 'Unnamed: 11']

# %%
df_transformed.head()
# Out:
# Commodity Group Month (ALL ITEMS, nan)  \
# 0                 Jan            124.8
# 1                 Feb            125.5
# 2                 Mar            125.6
# 3                 Apr            125.5
# 4                 May            125.6
#
# Commodity Group (01 -, Food and Non-Alcoholic Beverages)  \
# 0                                                  128.9
# 1                                                  129.3
# 2                                                  128.9
# 3                                                  128.7
# 4                                                  128.7
#
# Commodity Group (02 -, Alcoholic Beverages and Tobacco)  \
# 0                                                 174.7
# 1                                                 175.9
# 2                                                 176.3
# 3                                                 176.5
# 4                                                 176.8
#
# ...

# %%
df_transformed.head()
# Out:
# Commodity Group Month (ALL ITEMS, nan)  \
# 0                 Jan            124.8
# 1                 Feb            125.5
# 2                 Mar            125.6
# 3                 Apr            125.5
# 4                 May            125.6
#
# Commodity Group (01 -, Food and Non-Alcoholic Beverages)  \
# 0                                                  128.9
# 1                                                  129.3
# 2                                                  128.9
# 3                                                  128.7
# 4                                                  128.7
#
# Commodity Group (02 -, Alcoholic Beverages and Tobacco)  \
# 0                                                 174.7
# 1                                                 175.9
# 2                                                 176.3
# 3                                                 176.5
# 4                                                 176.8
#
# ...

# %%
df.head()
# Out:
#   Commodity Group                                   Commodity Group    Jan  \
# 1       ALL ITEMS                                               NaN  124.8
# 2            01 -                  Food and Non-Alcoholic Beverages  128.9
# 3            02 -                   Alcoholic Beverages and Tobacco  174.7
# 4            03 -                             Clothing and Footwear    117
# 5            04 -  Housing, Water, Electricity, Gas and Other Fuels  118.8
#
#      Feb    Mar    Apr    May Unnamed: 11    Jun    Jul    Aug    Sep    Oct  \
# 1  125.5  125.6  125.5  125.6         NaN  125.6  126.5  126.6  126.3  126.5
# 2  129.3  128.9  128.7  128.7         NaN  129.5  130.4  130.4  129.8  130.4
# 3  175.9  176.3  176.5  176.8         NaN    177    177  177.2  177.5  177.8
# 4  117.4  117.9  118.2  118.4         NaN  118.5  118.7    119  119.1  119.2
# 5  119.8  119.8  119.2  119.8         NaN  118.4    120  120.9  121.2  120.9
#
# ...

# %%
df_read_transformed = pd.read_csv("Transformed_Data/df_transformed.csv")

df_read_transformed.head()
# Out:
#   Month Unnamed: 1 Food and Non-Alcoholic Beverages  \
# 0   Jan      124.8                            128.9
# 1   Feb      125.5                            129.3
# 2   Mar      125.6                            128.9
# 3   Apr      125.5                            128.7
# 4   May      125.6                            128.7
#
#   Alcoholic Beverages and Tobacco  Clothing and Footwear  \
# 0                           174.7                  117.0
# 1                           175.9                  117.4
# 2                           176.3                  117.9
# 3                           176.5                  118.2
# 4                           176.8                  118.4
#
#    Housing, Water, Electricity, Gas and Other Fuels  \
# 0                                             118.8
# 1                                             119.8
# 2                                             119.8
# 3                                             119.2
# ...

# %%
# Slice columns from 'Unnamed: 15' to 'Personal Care, and Miscellaneous Goods and Services.1'
df_sliced = df_read_transformed.loc[:, 'Unnamed: 15':'Personal Care, and Miscellaneous Goods and Services.1']

# Concatenate with another DataFrame (e.g., df_other)
# result = pd.concat([df_other, df_slice], axis=1)

# If you just want to see the slice:

df_sliced.head()
# Out:
#   Unnamed: 15  Unnamed: 16  Food and Non-Alcoholic Beverages.1  \
# 0     2 0 2 5        128.4                               133.8
# 1         NaN        128.1                               132.6
# 2         NaN        127.8                               131.8
# 3         NaN        127.3                               129.9
# 4         NaN        127.2                               129.8
#
#    Alcoholic Beverages and Tobacco.1  Clothing and Footwear.1  \
# 0                              180.9                    119.7
# 1                              181.9                    119.9
# 2                              182.6                    120.0
# 3                              183.1                    120.1
# 4                              183.5                    120.3
#
#    Housing, Water, Electricity, Gas and Other Fuels.1  \
# 0                                              121.4
# 1                                              121.7
# ...

# %%
df_read_transformed = df_read_transformed.rename(columns={'Unnamed: 1': 'All items'})

# %%
df_read_transformed.head()
# Out:
#   Month All items Food and Non-Alcoholic Beverages  \
# 0   Jan     124.8                            128.9
# 1   Feb     125.5                            129.3
# 2   Mar     125.6                            128.9
# 3   Apr     125.5                            128.7
# 4   May     125.6                            128.7
#
#   Alcoholic Beverages and Tobacco  Clothing and Footwear  \
# 0                           174.7                  117.0
# 1                           175.9                  117.4
# 2                           176.3                  117.9
# 3                           176.5                  118.2
# 4                           176.8                  118.4
#
#    Housing, Water, Electricity, Gas and Other Fuels  \
# 0                                             118.8
# 1                                             119.8
# 2                                             119.8
# 3                                             119.2
# ...

# %%
df_read_transformed = df_read_transformed[df_read_transformed['Month'] != 'Unnamed: 11']

# %%
df_read_transformed = df_read_transformed.drop(columns=df_read_transformed.loc[:, 'Unnamed: 15':'Personal Care, and Miscellaneous Goods and Services.1'].columns)

# %%
df_read_transformed
# Out:
#            Month All items Food and Non-Alcoholic Beverages  \
# 0            Jan     124.8                            128.9
# 1            Feb     125.5                            129.3
# 2            Mar     125.6                            128.9
# 3            Apr     125.5                            128.7
# 4            May     125.6                            128.7
# 6            Jun     125.6                            129.5
# 7            Jul     126.5                            130.4
# 8            Aug     126.6                            130.4
# 9            Sep     126.3                            129.8
# 10           Oct     126.5                            130.4
# 11           Nov       127                            131.3
# 12           Dec     127.7                            132.3
# 13           Ave     126.1                      129.8833333
# 14   Unnamed: 30      Phil                              NCR
# 15  Year to Date       1.8                              2.3
#
# ...
