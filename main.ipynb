# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import plotly.express as px
import seaborn as sns

# %config InlineBackend.figure_format = 'retina'

import warnings
warnings.filterwarnings(action='ignore', category=FutureWarning)

# %%
# Load and clean your Excel file (skip the top header rows)
df = pd.read_excel("Statistical Tables on June 2025 CPI for All Income Households.xlsx",
                   sheet_name="table 1", skiprows=5)

# Rename the first column for clarity
df.rename(columns={df.columns[0]: "Commodity Group"}, inplace=True)

# Drop empty columns and rows
df.dropna(axis=1, how='all', inplace=True)
df = df[df["Commodity Group"].notna()]

# %%
df = df.rename(columns={'Unnamed: 1': 'Commodity Group'})

df.head()
# Out:
#                                     Commodity Group    Jan    Feb    Mar  \
# 1                                               NaN  124.8  125.5  125.6
# 2                  Food and Non-Alcoholic Beverages  128.9  129.3  128.9
# 3                   Alcoholic Beverages and Tobacco  174.7  175.9  176.3
# 4                             Clothing and Footwear    117  117.4  117.9
# 5  Housing, Water, Electricity, Gas and Other Fuels  118.8  119.8  119.8
#
#      Apr    May Unnamed: 11    Jun    Jul    Aug    Sep    Oct    Nov    Dec  \
# 1  125.5  125.6         NaN  125.6  126.5  126.6  126.3  126.5    127  127.7
# 2  128.7  128.7         NaN  129.5  130.4  130.4  129.8  130.4  131.3  132.3
# 3  176.5  176.8         NaN    177    177  177.2  177.5  177.8  178.7  179.5
# 4  118.2  118.4         NaN  118.5  118.7    119  119.1  119.2  119.3  119.4
# 5  119.2  119.8         NaN  118.4    120  120.9  121.2  120.9  120.7  121.2
#
#           Ave Unnamed: 30  Year to Date
# 1       126.1        Phil           1.8
# 2  129.883333         NCR           2.3
# 3     177.075       AONCR           1.7
# 4  118.508333         NaN           NaN
# 5  120.058333         NaN           NaN

# %% [markdown]
# Transform Data

# %%
# ...existing code...

# Set 'Commodity Group' as columns, months as index
df_transformed = df.set_index('Commodity Group').T

# Optional: Reset index and rename for clarity
df_transformed = df_transformed.reset_index().rename(columns={'index': 'Month'})

df_transformed.head()
# ...existing code...
# Out:
# Commodity Group Month    NaN Food and Non-Alcoholic Beverages  \
# 0                 Jan  124.8                            128.9
# 1                 Feb  125.5                            129.3
# 2                 Mar  125.6                            128.9
# 3                 Apr  125.5                            128.7
# 4                 May  125.6                            128.7
#
# Commodity Group Alcoholic Beverages and Tobacco Clothing and Footwear  \
# 0                                         174.7                   117
# 1                                         175.9                 117.4
# 2                                         176.3                 117.9
# 3                                         176.5                 118.2
# 4                                         176.8                 118.4
#
# Commodity Group Housing, Water, Electricity, Gas and Other Fuels  \
# 0                                                          118.8
# 1                                                          119.8
# 2                                                          119.8
# 3                                                          119.2
# 4                                                          119.8
#
# Commodity Group Furnishings, Household Equipment and Routine Household Maintenance  \
# 0                                                            120.2
# 1                                                            120.7
# 2                                                            121.1
# 3                                                            121.2
# 4                                                            121.5
#
# Commodity Group Health Transport Information and Communication  ... Health  \
# 0                121.5     128.9                         103.1  ...  124.5
# 1                  122     130.6                         103.1  ...  124.8
# 2                122.4     130.9                         103.1  ...  125.1
# 3                122.5     131.7                         103.2  ...  125.4
# 4                122.7     131.1                         103.2  ...  125.7
#
# Commodity Group Transport Information and Communication  \
# 0                   130.3                         103.3
# 1                   130.4                         103.4
# 2                   129.5                         103.5
# 3                   128.9                         103.5
# 4                   127.9                         103.6
#
# Commodity Group Recreation, Sport and Culture Education Services  \
# 0                                       117.3              120.3
# 1                                       117.7              120.3
# 2                                       117.7              120.3
# 3                                       117.8              120.3
# 4                                         118              120.3
#
# Commodity Group Restaurants and Accommodation Services Financial Services  \
# 0                                                129.6              142.4
# 1                                                130.1              142.4
# 2                                                130.4              142.4
# 3                                                130.7              142.4
# 4                                                130.8              142.4
#
# Commodity Group Personal Care, and Miscellaneous Goods and Services  NaN  NaN
# 0                                                            121.7   NaN  NaN
# 1                                                            122.1   NaN  NaN
# 2                                                            122.4   NaN  NaN
# 3                                                            122.6   NaN  NaN
# 4                                                            122.8   NaN  NaN
#
# [5 rows x 32 columns]

# %%
df_transformed
# Out:
# Commodity Group         Month    NaN Food and Non-Alcoholic Beverages  \
# 0                         Jan  124.8                            128.9
# 1                         Feb  125.5                            129.3
# 2                         Mar  125.6                            128.9
# 3                         Apr  125.5                            128.7
# 4                         May  125.6                            128.7
# 5                 Unnamed: 11    NaN                              NaN
# 6                         Jun  125.6                            129.5
# 7                         Jul  126.5                            130.4
# 8                         Aug  126.6                            130.4
# 9                         Sep  126.3                            129.8
# 10                        Oct  126.5                            130.4
# 11                        Nov    127                            131.3
# 12                        Dec  127.7                            132.3
# 13                        Ave  126.1                       129.883333
# 14                Unnamed: 30   Phil                              NCR
# 15               Year to Date    1.8                              2.3
#
# Commodity Group Alcoholic Beverages and Tobacco Clothing and Footwear  \
# 0                                         174.7                   117
# 1                                         175.9                 117.4
# 2                                         176.3                 117.9
# 3                                         176.5                 118.2
# 4                                         176.8                 118.4
# 5                                           NaN                   NaN
# 6                                           177                 118.5
# 7                                           177                 118.7
# 8                                         177.2                   119
# 9                                         177.5                 119.1
# 10                                        177.8                 119.2
# 11                                        178.7                 119.3
# 12                                        179.5                 119.4
# 13                                      177.075            118.508333
# 14                                        AONCR                   NaN
# 15                                          1.7                   NaN
#
# Commodity Group Housing, Water, Electricity, Gas and Other Fuels  \
# 0                                                          118.8
# 1                                                          119.8
# 2                                                          119.8
# 3                                                          119.2
# 4                                                          119.8
# 5                                                            NaN
# 6                                                          118.4
# 7                                                            120
# 8                                                          120.9
# 9                                                          121.2
# 10                                                         120.9
# 11                                                         120.7
# 12                                                         121.2
# 13                                                    120.058333
# 14                                                           NaN
# 15                                                           NaN
#
# Commodity Group Furnishings, Household Equipment and Routine Household Maintenance  \
# 0                                                            120.2
# 1                                                            120.7
# 2                                                            121.1
# 3                                                            121.2
# 4                                                            121.5
# 5                                                              NaN
# 6                                                            121.6
# 7                                                            121.8
# 8                                                            121.9
# 9                                                            122.1
# 10                                                           122.2
# 11                                                           122.8
# 12                                                             123
# 13                                                         121.675
# 14                                                             NaN
# 15                                                             NaN
#
# Commodity Group   Health Transport Information and Communication  ... Health  \
# 0                  121.5     128.9                         103.1  ...  124.5
# 1                    122     130.6                         103.1  ...  124.8
# 2                  122.4     130.9                         103.1  ...  125.1
# 3                  122.5     131.7                         103.2  ...  125.4
# 4                  122.7     131.1                         103.2  ...  125.7
# 5                    NaN       NaN                           NaN  ...    NaN
# 6                  122.9     130.7                         103.2  ...  125.9
# 7                  123.1     131.5                         103.2  ...    NaN
# 8                  123.2     129.6                         103.2  ...    NaN
# 9                  123.5     127.9                         103.2  ...    NaN
# 10                 123.7       128                         103.2  ...    NaN
# 11                   124     128.5                         103.2  ...    NaN
# 12                 124.2       130                         103.2  ...    NaN
# 13               122.975    129.95                       103.175  ...    NaN
# 14                   NaN       NaN                           NaN  ...    NaN
# 15                   NaN       NaN                           NaN  ...    NaN
#
# Commodity Group Transport Information and Communication  \
# 0                   130.3                         103.3
# 1                   130.4                         103.4
# 2                   129.5                         103.5
# 3                   128.9                         103.5
# 4                   127.9                         103.6
# 5                     NaN                           NaN
# 6                   128.6                         103.6
# 7                     NaN                           NaN
# 8                     NaN                           NaN
# 9                     NaN                           NaN
# 10                    NaN                           NaN
# 11                    NaN                           NaN
# 12                    NaN                           NaN
# 13                    NaN                           NaN
# 14                    NaN                           NaN
# 15                    NaN                           NaN
#
# Commodity Group Recreation, Sport and Culture Education Services  \
# 0                                       117.3              120.3
# 1                                       117.7              120.3
# 2                                       117.7              120.3
# 3                                       117.8              120.3
# 4                                         118              120.3
# 5                                         NaN                  r
# 6                                       118.3              121.6
# 7                                         NaN                NaN
# 8                                         NaN                NaN
# 9                                         NaN                NaN
# 10                                        NaN                NaN
# 11                                        NaN                NaN
# 12                                        NaN                NaN
# 13                                        NaN                NaN
# 14                                        NaN                NaN
# 15                                        NaN                NaN
#
# Commodity Group Restaurants and Accommodation Services Financial Services  \
# 0                                                129.6              142.4
# 1                                                130.1              142.4
# 2                                                130.4              142.4
# 3                                                130.7              142.4
# 4                                                130.8              142.4
# 5                                                  NaN                NaN
# 6                                                131.1              142.4
# 7                                                  NaN                NaN
# 8                                                  NaN                NaN
# 9                                                  NaN                NaN
# 10                                                 NaN                NaN
# 11                                                 NaN                NaN
# 12                                                 NaN                NaN
# 13                                                 NaN                NaN
# 14                                                 NaN                NaN
# 15                                                 NaN                NaN
#
# Commodity Group Personal Care, and Miscellaneous Goods and Services  NaN  NaN
# 0                                                            121.7   NaN  NaN
# 1                                                            122.1   NaN  NaN
# 2                                                            122.4   NaN  NaN
# 3                                                            122.6   NaN  NaN
# 4                                                            122.8   NaN  NaN
# 5                                                              NaN   NaN  NaN
# 6                                                            122.9   NaN  NaN
# 7                                                              NaN   NaN  NaN
# 8                                                              NaN   NaN  NaN
# 9                                                              NaN   NaN  NaN
# 10                                                             NaN   NaN  NaN
# 11                                                             NaN   NaN  NaN
# 12                                                             NaN   NaN  NaN
# 13                                                             NaN   NaN  NaN
# 14                                                             NaN   NaN  NaN
# 15                                                             NaN   NaN  NaN
#
# [16 rows x 32 columns]

# %%
import numpy as np

df_transformed = df_transformed.rename(columns={'Unknown': 'All items'})

# %%
df_transformed = df_transformed[df_transformed['Month'] != 'Unnamed: 11']

# %%
df_transformed.head()
# Out:
# Commodity Group Month All items Food and Non-Alcoholic Beverages  \
# 0                 Jan     124.8                            128.9
# 1                 Feb     125.5                            129.3
# 2                 Mar     125.6                            128.9
# 3                 Apr     125.5                            128.7
# 4                 May     125.6                            128.7
#
# Commodity Group Alcoholic Beverages and Tobacco Clothing and Footwear  \
# 0                                         174.7                   117
# 1                                         175.9                 117.4
# 2                                         176.3                 117.9
# 3                                         176.5                 118.2
# 4                                         176.8                 118.4
#
# Commodity Group Housing, Water, Electricity, Gas and Other Fuels  \
# 0                                                          118.8
# 1                                                          119.8
# 2                                                          119.8
# 3                                                          119.2
# 4                                                          119.8
#
# Commodity Group Furnishings, Household Equipment and Routine Household Maintenance  \
# 0                                                            120.2
# 1                                                            120.7
# 2                                                            121.1
# 3                                                            121.2
# 4                                                            121.5
#
# Commodity Group Health Transport Information and Communication  ... Health  \
# 0                121.5     128.9                         103.1  ...  124.5
# 1                  122     130.6                         103.1  ...  124.8
# 2                122.4     130.9                         103.1  ...  125.1
# 3                122.5     131.7                         103.2  ...  125.4
# 4                122.7     131.1                         103.2  ...  125.7
#
# Commodity Group Transport Information and Communication  \
# 0                   130.3                         103.3
# 1                   130.4                         103.4
# 2                   129.5                         103.5
# 3                   128.9                         103.5
# 4                   127.9                         103.6
#
# Commodity Group Recreation, Sport and Culture Education Services  \
# 0                                       117.3              120.3
# 1                                       117.7              120.3
# 2                                       117.7              120.3
# 3                                       117.8              120.3
# 4                                         118              120.3
#
# Commodity Group Restaurants and Accommodation Services Financial Services  \
# 0                                                129.6              142.4
# 1                                                130.1              142.4
# 2                                                130.4              142.4
# 3                                                130.7              142.4
# 4                                                130.8              142.4
#
# Commodity Group Personal Care, and Miscellaneous Goods and Services All items  \
# 0                                                            121.7        NaN
# 1                                                            122.1        NaN
# 2                                                            122.4        NaN
# 3                                                            122.6        NaN
# 4                                                            122.8        NaN
#
# Commodity Group All items
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#
# [5 rows x 32 columns]
